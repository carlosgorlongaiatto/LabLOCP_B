# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.ticker import NullFormatter
plt.rcParams['font.size'] = 14

# manifold.TSNE
from sklearn import manifold
from time import time
perplexities = [5, 10, 20, 50, 100]
n_components = 2 
Np = len(perplexities)
mycmap = ListedColormap(["blue","red","gold" ])

# DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
cpalette = ["blue","red","gold","black","magenta","green","cyan","#1CE6FF", "#FF34FF", "#FF4A46","#008941", "#006FA6", "#A30059", "#0000A6", "#63FFAC","#B79762", "#004D43", "#8FB0FF", "#997D87","#5A0007", "#809693","#1B4400", "#4FC601", "#3B5DFF", "#4A3B53","#886F4C","#34362D", "#B4A8BD", "#00A6AA", "#452C2C","#636375", "#A3C8C9", "#FF913F", "#938A81","#575329", "#00FECF", "#B05B6F"]
from collections import OrderedDict

# %% [markdown]
# ### Useful functions

# %%
def dist(x,i,j):
    return np.linalg.norm(x[i]-x[j])

def clustering(y):
    # Finds position of labels and returns a dictionary of cluster labels to data indices.
    yu = np.sort(np.unique(y))
    clustering = OrderedDict()
    for ye in yu:
        clustering[ye] = np.where(y == ye)[0]
    return clustering

def entropy(c, n_sample):
    # Measures the entropy of a cluster
    h = 0.
    for kc in c.keys():
        p=len(c[kc])/n_sample
        h+=p*np.log(p)
    h*=-1.
    return h

# Normalized mutual information function
# Note that this deals with the label permutation problem
def NMI(y_true, y_pred):
    """ Computes normalized mutual information: where y_true and y_pred are both clustering assignments
    """
    w = clustering(y_true)
    c = clustering(y_pred)
    n_sample = len(y_true)

    Iwc = 0.
    for kw in w.keys():
        for kc in c.keys():
            w_intersect_c=len(set(w[kw]).intersection(set(c[kc])))
            if w_intersect_c > 0:
                Iwc += w_intersect_c*np.log(n_sample*w_intersect_c/(len(w[kw])*len(c[kc])))
    Iwc/=n_sample
    Hc = entropy(c,n_sample)
    Hw = entropy(w,n_sample)

    return 2*Iwc/(Hc+Hw)

def plotting_ax(X, y, ax):
    # plotting function
    for i, yu in enumerate(np.unique(y)):
        pos = (y == yu)
        ax.scatter(X[pos,0], X[pos,1],c=cpalette[i%len(cpalette)],s=6)

# %% [markdown]
# ## Data and labels (L=3)
# In this example we know the labels, hence we can test the performances of t-SNE and DBSCAN.

# %%
# import 3D data with original noise
fname,fnamey="x_3d_L3.dat","y_3d_L3.dat"
data=np.loadtxt("DATA/"+fname, delimiter='\t')
y=np.loadtxt("DATA/"+fnamey,dtype=int)
N=len(data)
D=len(data[0])
print("N =",N,"  D =",D)
x=data
# Out:
# N = 1000   D = 3

# %% [markdown]
# ### Find the typical minimum distance between points
# This yields a typical scale, to be used as a reference for "eps"

# %%
mdist = np.zeros(N)
for i in range(N):
    dm = 1e100
    for j in range(N):
        if i!=j:
            dij = dist(x,i,j);
            if dij<dm:
                dm = dij
    mdist[i] = dm
    
mean_min_dist = mdist.mean()

print("mean minimum distance between points: ",mean_min_dist)  #useful to determine the epsilon of clustering
# Out:
# mean minimum distance between points:  18.55757910124019

# %% [markdown]
# ### t-SNE visualization, for true labels

# %%
np.random.seed(12345)
n_samples = N

(fig, subplots) = plt.subplots(1, Np, figsize=(3*Np, 2.7))

X_all = [None]
for i, perplexity in enumerate(perplexities):
    
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(data)

    ax = subplots[i]
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()
# Out:
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### DBSCAN: find labels by applying clustering

# %%
# DBSCAN has a few parameters, let's sweep over a few parameters and see what happens
np.random.seed(12345)
n_true_center=3
X2D = X_all[3] # best visualization above
X = data
y_true = y

if mean_min_dist<10:
    r=mean_min_dist
else:
    r = int(mean_min_dist)
eps_range = [r, 3*r, 6*r, 9*r, 12*r]
min_sample_range = [3,5,10,20]
fig, ax = plt.subplots(len(eps_range),len(min_sample_range),figsize=(15,18))
for i, eps in enumerate(eps_range):
    for j, min_samples in enumerate(min_sample_range):
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)
        y_hat = model.labels_
        plotting_ax(X2D,y_hat,ax[i,j])
        nmi=NMI(y_hat, y_true)
        ax[i,j].set_title('eps=%.2f, minPts=%i\nnmi=%.2f'%(eps,min_samples,nmi))
plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# ### Dendrogram

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

x = data

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None,linkage='single')
model = model.fit(x)

plt.figure(figsize=(13,6))
plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode="level", p=4)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %% [markdown]
# ## Data and labels (L=4)
# In this example we know the labels, hence we can test the performances of t-SNE and DBSCAN.

# %%
# import 3D data with original noise
fname,fnamey="x_3d_L4.dat","y_3d_L4.dat"
data=np.loadtxt("DATA/"+fname, delimiter='\t')
y=np.loadtxt("DATA/"+fnamey,dtype=int)
N=len(data)
D=len(data[0])
print("N =",N,"  D =",D)
x=data
# Out:
# N = 1000   D = 4

# %% [markdown]
# ### Find the typical minimum distance between points
# This yields a typical scale, to be used as a reference for "eps"

# %%
mdist = np.zeros(N)
for i in range(N):
    dm = 1e100
    for j in range(N):
        if i!=j:
            dij = dist(x,i,j);
            if dij<dm:
                dm = dij
    mdist[i] = dm
    
mean_min_dist = mdist.mean()

print("mean minimum distance between points: ",mean_min_dist)  #useful to determine the epsilon of clustering
# Out:
# mean minimum distance between points:  21.767814126488283

# %% [markdown]
# ### t-SNE visualization, for true labels

# %%
np.random.seed(12345)
n_samples = N

(fig, subplots) = plt.subplots(1, Np, figsize=(3*Np, 2.7))

X_all = [None]
for i, perplexity in enumerate(perplexities):
    
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(data)

    ax = subplots[i]
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()
# Out:
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### DBSCAN: find labels by applying clustering

# %%
# DBSCAN has a few parameters, let's sweep over a few parameters and see what happens
np.random.seed(12345)
n_true_center=3
X2D = X_all[3] # best visualization above
X = data
y_true = y

if mean_min_dist<10:
    r=mean_min_dist
else:
    r = int(mean_min_dist)
eps_range = [r, 3*r, 6*r, 9*r, 12*r]
min_sample_range = [3,5,10,20]
fig, ax = plt.subplots(len(eps_range),len(min_sample_range),figsize=(15,18))
for i, eps in enumerate(eps_range):
    for j, min_samples in enumerate(min_sample_range):
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)
        y_hat = model.labels_
        plotting_ax(X2D,y_hat,ax[i,j])
        nmi=NMI(y_hat, y_true)
        ax[i,j].set_title('eps=%.2f, minPts=%i\nnmi=%.2f'%(eps,min_samples,nmi))
plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# ## Data and labels (L=6, noise amplitude=1)
# In this example we know the labels, hence we can test the performances of t-SNE and DBSCAN.

# %%
# import 6D data with reduced noise
fname,fnamey="x_3d_L6_N_amp1.dat","y_3d_L6_N_amp1.dat"
data=np.loadtxt("DATA/"+fname, delimiter='\t')
y=np.loadtxt("DATA/"+fnamey,dtype=int)
N=len(data)
D=len(data[0])
print("N =",N,"  D =",D)
x=data

# adding rotation
from scipy.stats import ortho_group
rotation = True
if rotation:
    M_rot = ortho_group.rvs(D)
    x = np.dot(x, M_rot)
# Out:
# N = 1000   D = 6

# %% [markdown]
# ### Find the typical minimum distance between points
# This yields a typical scale, to be used as a reference for "eps"

# %%
mdist = np.zeros(N)
for i in range(N):
    dm = 1e100
    for j in range(N):
        if i!=j:
            dij = dist(x,i,j);
            if dij<dm:
                dm = dij
    mdist[i] = dm
    
mean_min_dist = mdist.mean()

print("mean minimum distance between points: ",mean_min_dist)  #useful to determine the epsilon of clustering
# Out:
# mean minimum distance between points:  18.488259716170536

# %% [markdown]
# ### t-SNE visualization, for true labels

# %%
np.random.seed(12345)
n_samples = N

(fig, subplots) = plt.subplots(1, Np, figsize=(3*Np, 2.7))

X_all = [None]
for i, perplexity in enumerate(perplexities):
    
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(data)

    ax = subplots[i]
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()
# Out:
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### DBSCAN: find labels by applying clustering

# %%
# DBSCAN has a few parameters, let's sweep over a few parameters and see what happens
np.random.seed(12345)
n_true_center=3
X2D = X_all[3] # best visualization above
X = data
y_true = y

if mean_min_dist<10:
    r=mean_min_dist
else:
    r = int(mean_min_dist)
eps_range = [r, 3*r, 6*r, 9*r, 12*r]
min_sample_range = [3,5,10,20]
fig, ax = plt.subplots(len(eps_range),len(min_sample_range),figsize=(15,18))
for i, eps in enumerate(eps_range):
    for j, min_samples in enumerate(min_sample_range):
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)
        y_hat = model.labels_
        plotting_ax(X2D,y_hat,ax[i,j])
        nmi=NMI(y_hat, y_true)
        ax[i,j].set_title('eps=%.2f, minPts=%i\nnmi=%.2f'%(eps,min_samples,nmi))
plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# ## Data and labels (L=6, noise amplitude = 10)
# In this example we know the labels, hence we can test the performances of t-SNE and DBSCAN.

# %%
# import 6D data
fname,fnamey="x_3d_L6_N_amp10.dat","y_3d_L6_N_amp10.dat"
data=np.loadtxt("DATA/"+fname, delimiter='\t')
y=np.loadtxt("DATA/"+fnamey,dtype=int)
N=len(data)
D=len(data[0])
print("N =",N,"  D =",D)
x=data
# Out:
# N = 1000   D = 6

# %% [markdown]
# ### Find the typical minimum distance between points
# This yields a typical scale, to be used as a reference for "eps"

# %%
mdist = np.zeros(N)
for i in range(N):
    dm = 1e100
    for j in range(N):
        if i!=j:
            dij = dist(x,i,j);
            if dij<dm:
                dm = dij
    mdist[i] = dm
    
mean_min_dist = mdist.mean()

print("mean minimum distance between points: ",mean_min_dist)  #useful to determine the epsilon of clustering
# Out:
# mean minimum distance between points:  28.459601384708932

# %% [markdown]
# ### t-SNE visualization, for true labels

# %%
np.random.seed(12345)
n_samples = N

(fig, subplots) = plt.subplots(1, Np, figsize=(3*Np, 2.7))

X_all = [None]
for i, perplexity in enumerate(perplexities):
    
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(data)

    ax = subplots[i]
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()
# Out:
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/eugenio/anaconda3/envs/Tf/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### DBSCAN: find labels by applying clustering

# %%
# DBSCAN has a few parameters, let's sweep over a few parameters and see what happens
np.random.seed(12345)
n_true_center=3
X2D = X_all[3] # best visualization above
X = data
y_true = y

if mean_min_dist<10:
    r=mean_min_dist
else:
    r = int(mean_min_dist)
eps_range = [r, 3*r, 6*r, 9*r, 12*r]
min_sample_range = [3,5,10,20]
fig, ax = plt.subplots(len(eps_range),len(min_sample_range),figsize=(15,18))
for i, eps in enumerate(eps_range):
    for j, min_samples in enumerate(min_sample_range):
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)
        y_hat = model.labels_
        plotting_ax(X2D,y_hat,ax[i,j])
        nmi=NMI(y_hat, y_true)
        ax[i,j].set_title('eps=%.2f, minPts=%i\nnmi=%.2f'%(eps,min_samples,nmi))
plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# ## Discussion

# %% [markdown]
# The performance of the t-SNE algorithm is not significantly affected by the addition of noisy dimensions.
#
# In contrast, the performance of the DBSCAN algorithm depends on the noise amplitude in the additional dimensions: if L is high (6), it finds a good result with low amplitude (1), while if L is low (4) it succeeds even with higher amplitude (10).
#
# Rotation does not change the result of t-SNE and DBSCAN. This can be justified by the fact that the orthonormal transformation preserves the distances between points which is a key factor for both algorithms.
